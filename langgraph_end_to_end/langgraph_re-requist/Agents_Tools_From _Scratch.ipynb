# %% [markdown]
# ### Lets First understand about the tools

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
api_wrapper = WikipediaAPIWrapper(top_k_results=5, doc_content_chars_max=100)

# %%
tool = WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
tool.name
# Out:
# 'wikipedia'

# %%
tool.description
# Out:
# 'A wrapper around Wikipedia. Useful for when you need to answer general questions about people, places, companies, facts, historical events, or other subjects. Input should be a search query.'

# %%
tool.args
# Out:
# {'query': {'description': 'query to look up on wikipedia',
#   'title': 'Query',
#   'type': 'string'}}

# %%
tool.return_direct
# Out:
# False

# %%
print(tool.invoke({"query": "langchain"}))
# Out:
# Page: LangChain
# Summary: LangChain is a software framework that helps facilitate the integration of

# %%
tool.run("langchain")
# Out:
# 'Page: LangChain\nSummary: LangChain is a software framework that helps facilitate the integration of '

# %%
from langchain_community.tools import YouTubeSearchTool
tool=YouTubeSearchTool()

# %%
tool.name
# Out:
# 'youtube_search'

# %%
tool.description
# Out:
# 'search for youtube videos associated with a person. the input to this tool should be a comma separated list, the first part contains a person name and the second a number that is the maximum number of video results to return aka num_results. the second part is optional'

# %%
tool.run("carry minati")
# Out:
# "['https://www.youtube.com/watch?v=lWBj9z2xDDs&pp=ygUMY2FycnkgbWluYXRp', 'https://www.youtube.com/watch?v=vcLRWiTNCbQ&pp=ygUMY2FycnkgbWluYXRp']"

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
tool=TavilySearchResults()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25680\568237837.py:2: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool=TavilySearchResults()

# %%
tool.invoke({"query": "What happened in the latest burning man floods"})
# Out:
# [{'title': "'There was no panic': Burner spirit prevails during flooding event at Burning Man | Latest Weather Clips | FOX Weather",
#   'url': 'https://www.foxweather.com/watch/6ba23da2-c0e6-5542-85b7-464b751ebb66',
#   'content': 'Fox Weather App on an iPhone, Fox Weather logo overlapping\nFox Weather live\n\n# \'There was no panic\': Burner spirit prevails during flooding event at Burning Man\n\n\'There was no panic\': Burner spirit prevails during flooding event at Burning Man\n\n## \'There was no panic\': Burner spirit prevails during flooding event at Burning Man\n\nFOX News Senior Correspondent Claudia Cowen is preparing to leave the Burning Man festival in Nevada after flooding caused festival goers to hunker down and wait for conditions to improve. Cowen said the "Burner spirit" prevailed and there was no panic was people waited to leave.\n\n## Latest Videos\n\nRoute 66 celebrates 100 years of the ‘Mother Road’\n\n### Route 66 celebrates 100 years of the ‘Mother Road’ [...] ### Route 66 celebrates 100 years of the ‘Mother Road’\n\nTemperatures to tumble below-average for millions across the East as May nears \n\n### Temperatures to tumble below-average for millions across the East as May nears\n\nLow-pressure system to lash Northeast with heavy rain, heightening flood and severe storm risks\n\n### Low-pressure system to lash Northeast with heavy rain, heightening flood and severe storm risks\n\nCommuter Forecast: April 29, 2026\n\n### Commuter Forecast: April 29, 2026\n\nLarge hail, destructive winds, confirmed tornado strike Mineral Wells, Texas\n\n### Large hail, destructive winds, confirmed tornado strike Mineral Wells, Texas\n\nFarm animals rescued after wandering away\n\n### Farm animals rescued after wandering away [...] ### Farm animals rescued after wandering away\n\nRadar shows severe storms moving through Mineral Wells, Texas\n\n### Radar shows severe storms moving through Mineral Wells, Texas\n\nTornado damage in Mineral Wells, Texas\n\n### Tornado damage in Mineral Wells, Texas\n\nHere\'s how much rain Dallas will get this month\n\n### Here\'s how much rain Dallas will get this month\n\nGeorgia weather warms up as firefighters continue battling massive wildfires\n\n### Georgia weather warms up as firefighters continue battling massive wildfires\n\nThis material may not be published, broadcast, rewritten, or\nredistributed. ©2026 FOX News Network, LLC. All\nrights reserved.',
#   'score': 0.5139862},
#  {'title': 'Burning Man 2025 opens with risk of rain, flash floods, high winds',
#   'url': 'https://www.rgj.com/story/news/2025/08/24/burning-man-2025-opens-with-risk-of-rain-flash-floods-high-winds/85808130007/',
#   'content': '# Burning Man weather: Heat, humidity Sunday could put Black Rock City at risk of flooding\n\nPortrait of Siobhan McAndrew\n\nThe National Weather Service issued a flood watch on Sunday, the official first day of Burning Man, for the Black Rock Desert.\n\nRain could be an issue as 70,000 people head out to the playa over the next week. The annual festival runs Aug. 24 through Sept. 1.\n\nThe weather service started warning of possible monsoon-like conditions at least a week ahead of the festival. In 2023, heavy storms and rain stranded thousands of people and officials closed the gates in and out of the festival. [...] With humidity at about 57% in Reno, the conditions are there for as much as an inch rain in parts of Northern Nevada through Tuesday, Giralte said.\n\n“The playa out there is susceptible to flooding and muddy conditions,“ she said. “And it doesn’t take much.”\n\nShe said even one-tenth of an inch of rain on the playa can cause muddy conditions.\n\n“I’m not going to say it is going to happen or it’s not going to happen, but people should make preparations for their shelters,” she said. “We want people to have an idea of what could happen.” [...] While the Black Rock Desert and nearby town of Gerlach saw gusts topping 50 mph Saturday, there wasn’t much rain on the playa from bands of thunderstorms that hit the region. Reports of tents blowing away were all over Burning Man social media pages Sunday morning.\n\nSunday could be a different situation depending on how things shape up the rest of the day, according to National Weather Service meteorologist Gigi Giralte.\n\nPeople navigate the playa during sunrise at Burning Man in Nevada on Aug. 29, 2024.\n\nClearing clouds may seem like a good thing, but it actually increases the risk of thunderstorms and rain as temperatures rise, Giralte said.',
#   'score': 0.459295},
#  {'title': 'Burning Man gate open; officials take wait-and-see approach on weather',
#   'url': 'https://www.rgj.com/story/news/2025/08/24/burning-man-opens-gates-following-massive-wind-storm-livestream-up/85806744007/',
#   'content': 'The gate closure comes as the National Weather Service issued wind and flood advisories. Wind gusts of up to 50 mph were forecast until about 9 p.m.\n\nThe estimated wait for cars already on Gate Road waiting to get into the city is 7 hours.\n\n"If you’re in Reno, delay your travel and keep an eye on this channel for updates. If you are in Black Rock City, secure your structures and belongings," the post just after 7 p.m. on Burning Man\'s website said.\n\n## Burning Man closes entry gates as high winds, rain hit playa\n\nJust after 6 p.m. Sunday, Burning Man\'s website announced the gates to the festival closed to all traffic in and out of the playa. The National Weather Service predicted a late Sunday afternoon storm that had a chance of causing flooding. [...] Burning Man posted that the rain and wind have mostly stopped or slowed, with a small amount of standing water on the playa.\n\nFor vehicles stopped on the Gate Road, the estimated time to get into Black Rock City is seven hours once gates open, Burning Man said.\n\nTraffic is being stopped in Wadsworth, and Burning Man is encouraging anyone still in Reno to stay there until further notice.\n\nVehicles are not allowed to drive on the playa, and the BRC airport is closed, Burning Man said.\n\n## Burning Man: Stay in Reno if you have not left for the playa yet\n\nBurning Man is telling people to stay in Reno and delay traveling to the playa. The gates closed around 6 p.m. Sunday and there was no estimate on when they would reopen. [...] Vehicles on the Gate Road into Burning Man are starting to move into Black Rock City after the gates reopened early Monday.\n\nTraffic is still being turned around on Highway 447 at Wadsworth, and Burning Man is recommending people stay in Reno if they have not yet departed for the playa.\n\nThe gate into Burning Man was closed around 6 p.m. Sunday after wind and rain hit the playa, causing muddy and white-out conditions.\n\n"The rain and wind have stopped in BRC. The ground is drying up and vehicles on Gate Road are starting to move into the city," Burning Man posted on its website early Monday. "Take your time and follow instructions from staff."\n\nTraffic on Gate Road began moving around 5 a.m. Monday.',
#   'score': 0.40570828},
#  {'title': 'Burners defend Burning Man after several days of ... - YouTube',
#   'url': 'https://www.youtube.com/watch?v=2ksYMt2RzyA',
#   'content': "It's been a wild ride for those either at Burning Man 2025 or trying to get there. Windstorms, thunder, lightning, and rain have hampered",
#   'score': 0.31964198},
#  {'title': 'Dust storm flips tents at Burning Man as forecasters warn of ... - MSN',
#   'url': 'https://www.msn.com/en-us/weather/topstories/dust-storm-flips-tents-at-burning-man-as-forecasters-warn-of-looming-flood-danger/ar-AA1L7RiV?cvid=d722514d4ab744adcf8158b3cd852115&ei=7',
#   'content': 'Winds of up to 50 mph stirred dust in the Black Rock Desert so fiercely that Burning Man participants reported not being able to see beyond a foot.',
#   'score': 0.28448203}]

# %%
from langchain_core.tools import tool

# %%
@tool
def get_word_length(word:str) -> int:
    """Returns the length of a word."""
    return len(word)

get_word_length.invoke("abc")
# Out:
# 3

# %%
@tool
def multiply(a:int, b:int) -> int:
    """ Multipy two numbers"""
    return a * b

# %%
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# Multipy two numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
